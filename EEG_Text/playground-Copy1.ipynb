# %%
# %load_ext autoreload
# %autoreload 2

# %%
from mamba_ssm import Mamba
# from transformers import MambaConfig, MambaForCausalLM, AutoTokenizer


import torch
import numpy as np
import torch
import torch.nn as nn
from torch import tensor
import scipy as sp

# import torchvision
# import torchvision.transforms as transforms

import torch
from torch.utils.data import DataLoader, TensorDataset
from mamba_ssm.modules.block import Block
from functools import partial


from mamba_model import MambaEEG
from mamba_ssm.models.config_mamba import MambaConfig
from models import *

# %% [markdown]
# # @TODO SUBJECT SPEFICIC LAYER!!!

# %%
# !ls
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# task2-NR-2.0-dataset.pickle

# %%
import pickle

# %%
pic = pickle.load(open('dataset/ZuCo/task2-NR-2.0/pickle/task2-NR-2.0-dataset.pickle','rb'))

# %%
pic['YAG'][0]['word'][0]['word_level_EEG']['TRT']
# Out:
# {'TRT_t1': array([1.40261447, 0.90061718, 0.72813612, 0.8450979 , 0.8296752 ,
#         0.73214447, 0.58177119, 0.69973809, 0.69607663, 0.57748842,
#         0.81024599, 0.73605788, 0.6994341 , 0.56968468, 0.43644938,
#         0.3669585 , 1.05047274, 0.6224817 , 0.36138946, 1.32200301,
#         0.50691241, 0.41167128, 0.66427219, 0.55471057, 1.079301  ,
#         1.08636475, 0.41377681, 0.48100454, 0.64423406, 0.92937535,
#         3.37432265, 0.62905771, 0.2836242 , 0.39913288, 0.64353126,
#         2.71244669, 2.97693324, 0.47522125, 1.22589278, 0.77576309,
#         0.42423472, 0.6610043 , 0.8535791 , 0.96275437, 1.03400195,
#         1.1759721 , 0.36638731, 0.61021495, 0.85321581, 0.94697195,
#         0.97522181, 0.86939681, 0.6201458 , 0.72206306, 0.91180223,
#         0.97550368, 0.81291008, 0.77447575, 0.73569745, 0.69399786,
#         1.10057044, 0.35573947, 1.77995169, 1.16867232, 0.87228978,
#         0.80914646, 1.13957834, 2.61480427, 1.94425786, 0.54974329,
#         0.68824834, 0.75073701, 0.86731684, 1.71961737, 1.92836344,
#         1.18865764, 0.86608237, 0.8206389 , 1.25489116, 0.91841114,
#         0.79341215, 0.72871685, 1.06955755, 0.87316197, 0.71986955,
#         0.74346691, 0.69095713, 0.71742064, 1.13278687, 1.13657141,
#         0.82633013, 0.75451761, 0.7965042 , 0.86548781, 3.09661388,
#         1.37029302, 0.65518242, 0.43621981, 0.97519779, 4.13811302,
#         3.86160326, 1.72337735, 0.54371333, 0.88487977, 1.22224987]),
#  'TRT_t2': array([2.07667732, 1.48849797, 0.83906323, 0.94584745, 0.7555474 ,
#         0.65507191, 1.35172057, 1.24553263, 1.13237834, 0.75497574,
#         0.87278444, 1.88408911, 1.24915266, 1.16640902, 0.95724064,
#         0.72419667, 2.22433567, 0.89549494, 0.79337996, 1.43154705,
#         0.77223921, 0.78462708, 0.71373218, 0.42916089, 0.56245732,
#         1.34310448, 0.73946548, 0.62844789, 0.55671841, 0.41784829,
#         2.44972873, 0.86069608, 0.62467825, 0.47278088, 0.63717681,
#         2.13378787, 2.66645932, 0.59031522, 0.44940525, 0.68551791,
#         0.6553641 , 0.84079945, 0.57381201, 0.43494827, 0.52506077,
#         0.68449217, 0.62887537, 0.92499459, 0.80993629, 0.58994323,
#         2.08839226, 1.27659667, 3.58703232, 3.76348519, 3.68640661,
#         3.5419476 , 3.71936774, 3.17913747, 3.79587865, 4.09471226,
#         3.94818449, 3.66920018, 4.92747545, 3.62261176, 3.80640745,
#         3.88887501, 3.99531484, 2.90825534, 3.25062442, 2.34119773,
#         1.89695036, 0.59462857, 1.96366262, 1.87875915, 1.33154476,
#         1.23567653, 1.32573891, 1.43957376, 1.90621936, 1.61550581,
#         1.39470053, 1.83000875, 2.19117618, 1.92671251, 1.71717131,
#         1.70340478, 1.90445435, 2.34686255, 2.517977  , 1.93614066,
#         2.0103569 , 2.01560831, 1.4849    , 0.55931711, 2.69207549,
#         2.19750142, 2.24507618, 1.94994259, 1.21353447, 3.92827606,
#         3.54602337, 2.71423316, 2.4541297 , 1.46535957, 4.40623188,
#         5.28888607, 2.92488217, 1.77788341, 1.52256429, 1.3564477 ])}

# %%
pic['YAG'][0]['sentence_level_EEG']['mean_t1']
# Out:
# array([3.99931383, 1.66266501, 1.1260891 , 1.09210467, 1.11598217,
#        1.16841018, 3.06357574, 1.57445288, 1.35179389, 1.15584254,
#        1.05645442, 2.63251996, 1.66265202, 1.51152825, 1.20166445,
#        1.15183032, 2.94588852, 1.44206679, 1.14164686, 2.10525537,
#        1.08507633, 1.03475666, 0.9827835 , 1.16995919, 1.71615124,
#        1.6393292 , 0.83065325, 0.8150444 , 1.01834726, 1.50741231,
#        3.38615656, 0.89979148, 0.76764631, 0.80608618, 1.13148689,
#        3.05741453, 2.91894507, 1.12165987, 1.34454691, 1.18896484,
#        1.43577671, 1.08912849, 1.27571881, 1.45165181, 1.57095182,
#        1.70521653, 2.478441  , 1.17878437, 1.39465129, 1.42945838,
#        1.50007725, 1.53819156, 1.2499299 , 1.34544313, 1.56442928,
#        1.61160123, 1.46748006, 1.64660895, 1.65201652, 1.5647397 ,
#        1.77583063, 1.7138586 , 1.79244626, 1.60919929, 1.29906607,
#        1.14817905, 1.429672  , 2.11905003, 2.20650697, 1.84685791,
#        1.49745357, 0.8277719 , 0.68556255, 2.10811996, 1.81952858,
#        1.1564393 , 0.9595592 , 1.11570871, 1.97325814, 1.5424639 ,
#        1.19482088, 0.98033929, 2.16171217, 1.98576736, 1.29863644,
#        1.08316994, 1.41445041, 0.83537352, 1.53106511, 1.97344232,
#        1.47091246, 1.09420431, 0.97307056, 1.10434365, 3.38925862,
#        2.06197762, 1.25356889, 0.89308351, 1.12209666, 4.57220364,
#               nan, 2.17232633, 1.10903907, 1.08784044, 1.77556515])

# %%
for key in pic.keys():
    try:
        print(pic[key][0]['sentence_level_EEG'].keys())
    except:
        continue
# Out:
# dict_keys(['mean_t1', 'mean_t2', 'mean_a1', 'mean_a2', 'mean_b1', 'mean_b2', 'mean_g1', 'mean_g2'])
# dict_keys(['mean_t1', 'mean_t2', 'mean_a1', 'mean_a2', 'mean_b1', 'mean_b2', 'mean_g1', 'mean_g2'])
# dict_keys(['mean_t1', 'mean_t2', 'mean_a1', 'mean_a2', 'mean_b1', 'mean_b2', 'mean_g1', 'mean_g2'])
# dict_keys(['mean_t1', 'mean_t2', 'mean_a1', 'mean_a2', 'mean_b1', 'mean_b2', 'mean_g1', 'mean_g2'])
# dict_keys(['mean_t1', 'mean_t2', 'mean_a1', 'mean_a2', 'mean_b1', 'mean_b2', 'mean_g1', 'mean_g2'])
# dict_keys(['mean_t1', 'mean_t2', 'mean_a1', 'mean_a2', 'mean_b1', 'mean_b2', 'mean_g1', 'mean_g2'])
# dict_keys(['mean_t1', 'mean_t2', 'mean_a1', 'mean_a2', 'mean_b1', 'mean_b2', 'mean_g1', 'mean_g2'])
# dict_keys(['mean_t1', 'mean_t2', 'mean_a1', 'mean_a2', 'mean_b1', 'mean_b2', 'mean_g1', 'mean_g2'])
# dict_keys(['mean_t1', 'mean_t2', 'mean_a1', 'mean_a2', 'mean_b1', 'mean_b2', 'mean_g1', 'mean_g2'])
# dict_keys(['mean_t1', 'mean_t2', 'mean_a1', 'mean_a2', 'mean_b1', 'mean_b2', 'mean_g1', 'mean_g2'])
# dict_keys(['mean_t1', 'mean_t2', 'mean_a1', 'mean_a2', 'mean_b1', 'mean_b2', 'mean_g1', 'mean_g2'])
# dict_keys(['mean_t1', 'mean_t2', 'mean_a1', 'mean_a2', 'mean_b1', 'mean_b2', 'mean_g1', 'mean_g2'])
# dict_keys(['mean_t1', 'mean_t2', 'mean_a1', 'mean_a2', 'mean_b1', 'mean_b2', 'mean_g1', 'mean_g2'])
# dict_keys(['mean_t1', 'mean_t2', 'mean_a1', 'mean_a2', 'mean_b1', 'mean_b2', 'mean_g1', 'mean_g2'])

# %%
pic['YAK'][2].keys()
# Out:
# dict_keys(['content', 'sentence_level_EEG', 'word', 'word_tokens_has_fixation', 'word_tokens_with_mask', 'word_tokens_all'])

# %%
model_name = 'bert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(model_name)

encoder = HuggingFaceEncoder(model_name)


mm = MambaConfig(ssm_cfg = {'layer':'Mamba1'}, d_model = 64)

ee = EEGEncoder(mamba_config=mm, embedding = 'last').cuda()

# %%
test = torch.rand((1,20, 22)).cuda()
inputs = tokenizer(["This is a sentence"], return_tensors='pt', padding=True, truncation=True)

# %%
# inputs.to('cuda')

# %%
etc = EEGTextCLIP(ee, encoder).cuda()

# %%
# torch.tensor("This is a sentence")

# %%
etc(test, inputs.to('cuda'))
# Out:
# (tensor([[ 0.1636,  3.0080, -0.1541,  ...,  0.7479, -0.4782, -0.1189]],
#         device='cuda:0', grad_fn=<NativeLayerNormBackward0>),
#  tensor([[-0.0857, -0.5431, -0.4438,  ..., -0.4187, -0.6993,  1.0623]],
#         device='cuda:0', grad_fn=<NativeLayerNormBackward0>))

# %%
# Example Usage
model_name = 'bert-base-uncased'
encoder = HuggingFaceEncoder(model_name)

# For sentences
sentences = ["This is a sentence.", "Here is another one."]
sentence_embeddings = encoder.process_sentences(sentences, pooling='mean')
print("Sentence embeddings:", sentence_embeddings)
# Out:
# Sentence embeddings: tensor([[[ 0.0884, -0.1475,  0.1752,  ..., -0.0535, -0.1021,  0.5540]],
#
#         [[ 0.1275, -0.2232,  0.1702,  ..., -0.0162,  0.0776,  0.1723]]],
#        grad_fn=<StackBackward0>)

# %%
sentence_embeddings.shape
# Out:
# torch.Size([2, 1, 768])

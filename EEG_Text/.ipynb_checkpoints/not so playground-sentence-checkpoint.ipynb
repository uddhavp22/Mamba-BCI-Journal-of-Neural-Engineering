# %%
# %load_ext autoreload
# %autoreload 2

# %%
from mamba_ssm import Mamba
# from transformers import MambaConfig, MambaForCausalLM, AutoTokenizer


import torch
import numpy as np
import torch
import torch.nn as nn
from torch import tensor
import scipy as sp

# import torchvision
# import torchvision.transforms as transforms

import torch
from torch.utils.data import DataLoader, TensorDataset
from mamba_ssm.modules.block import Block
from functools import partial


from mamba_model import MambaEEG
from mamba_ssm.models.config_mamba import MambaConfig
from models import *

# %%
from tqdm.notebook import tqdm
import os
import h5py

# %%
def load_matlab_string(matlab_extracted_object):
    """
    Converts a string loaded from h5py into a python string
    :param matlab_extracted_object:     (h5py)  matlab string object
    :return:
        extracted_string    (str)   translated string
    """

    # print((chr(c) for c in matlab_extracted_object))
    extracted_string = u''.join(chr(c) for c in matlab_extracted_object[:].flatten())
    # print(extracted_string)
    return extracted_string

# %%
task = "NR"

rootdir = "/radraid/spanchavati/eegtotext/zuco-benchmark/data/"

print('##############################')
print(f'start processing ZuCo task2-NR-2.0...')

dataset_dict = {}

for file in tqdm(os.listdir(rootdir)[::-1]):
    if file.endswith(task+".mat"):
        print(file)

        file_name = rootdir + file

        # print('file name:', file_name)
        subject = file_name.split("ts")[1].split("_")[0]
        # print('subject: ', subject)

        # exclude YMH due to incomplete data because of dyslexia
        if subject != 'YMH':
            pass

        f = h5py.File(file_name,'r')
        print('keys in f:', list(f.keys()))
        try:
            sentence_data = f['sentenceData']
            # break
        except:
            continue

        contents = []
        rawEEG = []
        for i in range(sentence_data['rawData'].len()):
            content = load_matlab_string(f[sentence_data['content'][i][0]])
            raweeg = f[sentence_data['rawData'][i][0]]

            contents.append(content)
            rawEEG.append(np.array(raweeg))

        dataset_dict[subject] = {'content': contents, 'eeg': rawEEG}
        #     # contents.append(sentence_data['content'])
# Out:
# ##############################
# start processing ZuCo task2-NR-2.0...
#   0%|          | 0/54 [00:00<?, ?it/s]
# resultsYAG_NR.mat
# keys in f: ['#refs#', 'sentenceData']
# resultsXAH_NR.mat
# keys in f: []
# resultsXLS_NR.mat
# keys in f: []
# resultsYRK_NR.mat
# keys in f: ['#refs#', 'sentenceData']
# resultsYDR_NR.mat
# keys in f: ['#refs#', 'sentenceData']
# resultsYRP_NR.mat
# keys in f: ['#refs#', 'sentenceData']
# resultsYFR_NR.mat
# keys in f: ['#refs#', 'sentenceData']
# resultsYHS_NR.mat
# keys in f: ['#refs#', 'sentenceData']
# resultsXDT_NR.mat
# keys in f: []
# resultsXBB_NR.mat
# keys in f: []
# resultsYSL_NR.mat
# keys in f: ['#refs#', 'sentenceData']
# resultsYTL_NR.mat
# keys in f: ['#refs#', 'sentenceData']
# resultsXWS_NR.mat
# keys in f: []
# resultsYIS_NR.mat
# keys in f: ['#refs#', 'sentenceData']
# resultsYMD_NR.mat
# keys in f: ['#refs#', 'sentenceData']
# resultsXBD_NR.mat
# keys in f: []
# resultsYFS_NR.mat
# keys in f: ['#refs#', 'sentenceData']
# resultsXSS_NR.mat
# keys in f: []
# resultsYSD_NR.mat
# keys in f: ['#refs#', 'sentenceData']
# resultsYLS_NR.mat
# keys in f: ['#refs#', 'sentenceData']
# resultsXPB_NR.mat
# keys in f: []
# resultsXTR_NR.mat
# keys in f: []
# resultsXSE_NR.mat
# keys in f: []
# resultsYDG_NR.mat
# keys in f: ['#refs#', 'sentenceData']
# resultsYAC_NR.mat
# keys in f: ['#refs#', 'sentenceData']
# resultsYAK_NR.mat
# keys in f: ['#refs#', 'sentenceData']

# %%
import random
from torch.utils.data import Dataset
from transformers import AutoTokenizer
import numpy as np
import torch

class EEGTextDatasetV2(Dataset):
    def __init__(self, data_dict, subject_keys, tokenizer_name='bert-base-uncased', maxlen=15*500, mode='within'):
        self.tokenizer = AutoTokenizer.from_pretrained(tokenizer_name)
        self.maxlen = maxlen
        self.data = []
        self.subject_to_id = {}
        self.mode = mode  # 'within', 'cross', or 'zero-shot'
        
        self.load_data(data_dict, subject_keys)

    def load_data(self, data_dict, subject_keys):
        for i, key in enumerate(subject_keys):
            patient_data = data_dict[key]
            sentences = np.array(patient_data['content'])
            eeg_data = patient_data['eeg']
            
            if key not in self.subject_to_id:
                self.subject_to_id[key] = len(self.subject_to_id)
            subject_id = self.subject_to_id[key]
            
            mean, std = self.incremental_mean_std(eeg_data)

            for sentence, eeg in zip(sentences, eeg_data):
                eeg_processed, attention_mask = self.process_eeg(eeg, mean, std)
                if eeg_processed is not None:
                    self.data.append({
                        'sentence': sentence,
                        'eeg': eeg_processed,
                        'eeg_attention_mask': attention_mask,
                        'subject_id': subject_id
                    })

    def __getitem__(self, idx):
        item = self.data[idx]
        
        tokenized = self.tokenizer(item['sentence'], return_tensors='pt', padding='max_length', truncation=True)
        
        return {
            'input_ids': tokenized['input_ids'][0],
            'attention_mask': tokenized['attention_mask'][0],
            'eeg': torch.nan_to_num(torch.tensor(item['eeg']), posinf=0, neginf=0).float(),
            'eeg_attention_mask': torch.tensor(item['eeg_attention_mask']),
            'subject_id': torch.tensor(item['subject_id'], dtype=torch.long)
        }

    def __len__(self):
        return len(self.data)

    def process_eeg(self, eeg_data, mean, std):
        """
        Normalize EEG by computing total channel mean and std.
        Right pad EEG with 0s to self.maxlen, throw error if eeg_data is longer than maxlen.
        """
        if eeg_data.shape[0] < 100:
            return None, None
    
        normalized_eeg = (eeg_data - mean) / std
        
        # Check if EEG data length exceeds maxlen
        if normalized_eeg.shape[0] > self.maxlen:
            print(f"EEG data length {normalized_eeg.shape[0]} exceeds maxlen {self.maxlen}")
            return None, None
        
        # Create attention mask
        attention_mask = np.zeros((self.maxlen,))
        attention_mask[:normalized_eeg.shape[0]] = 1
        
        # Right pad EEG data with zeros
        padded_eeg = np.zeros((self.maxlen, normalized_eeg.shape[1]))
        padded_eeg[:normalized_eeg.shape[0], :] = normalized_eeg
        
        return padded_eeg, attention_mask
    
    def incremental_mean_std(self, data_list):
        """
        Calculate mean and standard deviation incrementally for a list of EEG data arrays.
        """
        n_total = 0
        mean = 0
        M2 = 0
        for data in data_list:
            n = data.shape[0]
            if n < 100:
                continue
        n_total += n
        delta = data - mean
        mean += np.nansum(delta, axis=0) / n_total
        delta2 = data - mean
        M2 += np.nansum(delta * delta2, axis=0)

        variance = M2 / (n_total - 1)
        std = np.sqrt(variance)
        return mean, std

def create_data_splits(data_dict, train_ratio=0.8, val_ratio=0.1, test_ratio=0.1):
    all_sentences = set()
    for subject_data in data_dict.values():
        all_sentences.update(subject_data['content'])
    
    # Select test (zero-shot) sentences
    test_sentences = set(random.sample(all_sentences, int(len(all_sentences) * test_ratio)))
    
    train_val_data = {subject: {'content': [], 'eeg': []} for subject in data_dict}
    test_data = {subject: {'content': [], 'eeg': []} for subject in data_dict}

    for subject, subject_data in data_dict.items():
        for sentence, eeg in zip(subject_data['content'], subject_data['eeg']):
            if sentence in test_sentences:
                test_data[subject]['content'].append(sentence)
                test_data[subject]['eeg'].append(eeg)
                # print(eeg)
            else:
                train_val_data[subject]['content'].append(sentence)
                train_val_data[subject]['eeg'].append(eeg)
    
    # Split remaining data into train and validation
    train_data = {subject: {'content': [], 'eeg': []} for subject in data_dict}
    val_data = {subject: {'content': [], 'eeg': []} for subject in data_dict}

    for subject, subject_data in train_val_data.items():
        n = len(subject_data['content'])
        train_idx = int(n * (train_ratio / (train_ratio + val_ratio)))
        
        train_data[subject]['content'] = subject_data['content'][:train_idx]
        train_data[subject]['eeg'] = subject_data['eeg'][:train_idx]
        
        val_data[subject]['content'] = subject_data['content'][train_idx:]
        val_data[subject]['eeg'] = subject_data['eeg'][train_idx:]

    return train_data, val_data, test_data

def create_datasets(data_dict, tokenizer_name, maxlen):
    train_data, val_data, test_data = create_data_splits(data_dict)
    
    # # Within-subject datasets
    # train_within = EEGTextDatasetV2(train_data, list(train_data.keys()), tokenizer_name, maxlen, mode='within')
    # val_within = EEGTextDatasetV2(val_data, list(val_data.keys()), tokenizer_name, maxlen, mode='within')
    
    # Cross-subject dataset
    train_data = {subject: {'content': train_data[subject]['content'],
                          'eeg': train_data[subject]['eeg']}
                for subject in train_data.keys()}
    val_data = {subject: {'content': val_data[subject]['content'],
                          'eeg':val_data[subject]['eeg']} for subject in val_data.keys()}
    
    train_cross = EEGTextDatasetV2(train_data, list(train_data.keys()), tokenizer_name, maxlen, mode='cross')
    val_cross = EEGTextDatasetV2(val_data, list(val_data.keys()), tokenizer_name, maxlen, mode='cross')
    
    # Test dataset (zero-shot)
    test = EEGTextDatasetV2(test_data, list(test_data.keys()), tokenizer_name, maxlen, mode='test')
    
    return train_cross, val_cross, test # train_within, val_within,

# %%
model_name = 'bert-base-cased'
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
tokenizer_name = model_name
maxlen = 30*500

# %%
train_ds, val_ds, test_ds = create_datasets(dataset_dict, tokenizer_name, maxlen)

# %%
# Create dataloaders
train_dataloader = DataLoader(train_ds, batch_size=4, shuffle=True,num_workers= 4)
val_dataloader = DataLoader(val_ds, batch_size=4, shuffle=False, num_workers=4)
test_dataloader = DataLoader(test_ds, batch_size = 4, shuffle = False, num_workers=4)

# %%
# del model
# del batch

# import gc
# gc.collect()

# torch.cuda.empty_cache()

# %%
encoder = HuggingFaceEncoder(model_name, freeze = True)


mm = MambaConfig(ssm_cfg = {'layer':'Mamba1'}, d_model = 32, n_layer = 12)

ee = EEGEncoder(n_channels = 105, max_length= maxlen, mamba_config=mm, embedding = 'mean', patient_ids = list(train_ds.subject_to_id.values()))



model = EEGTextCLIP(
    eeg_encoder=ee,
    text_encoder=encoder,
    text_embedding_dims=768,
    projection_dims=256,
    dropout=0.1,
    temperature=1.0,
    weight_decay=1e-6,
    head_lr=1e-4,
    image_encoder_lr=1e-4,
    text_encoder_lr=1e-4,
    lr_scheduler_patience=5.0,
    lr_scheduler_factor=0.8
)
# Out:
# /raid/spanchavati/anaconda3/envs/eegtext/lib/python3.8/site-packages/pytorch_lightning/utilities/parsing.py:197: UserWarning: Attribute 'eeg_encoder' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['eeg_encoder'])`.
#   rank_zero_warn(
# /raid/spanchavati/anaconda3/envs/eegtext/lib/python3.8/site-packages/pytorch_lightning/utilities/parsing.py:197: UserWarning: Attribute 'text_encoder' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['text_encoder'])`.
#   rank_zero_warn(

# %%
# # Define callbacks
# checkpoint_callback = ModelCheckpoint(
#     monitor='val/loss',
#     dirpath='checkpoints/',
#     filename='eeg-text-clip-{epoch:02d}-{val_loss:.2f}',
# )

# trainer = Trainer(
#     max_epochs=10,
#     accelerator='gpu',
#     devices=[0],
#     num_sanity_val_steps=10,
#     # fast_dev_run=5,
#     # callbacks=[checkpoint_callback],
#     # log_every_n_steps=1  # Added logging for debugging
# )


# # Train the model
# trainer.fit(model, train_dataloaders=train_dataloader, val_dataloaders=val_dataloader)

# %% [markdown]
# <!-- # for batch in train_dataloader:
# #     break -->

# %%
# 
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# batch['subject_id']

# %%
# del model
# del batch

# torch.cuda.empty_cache()

# %%
from torch.utils.tensorboard import SummaryWriter
import numpy as np

device = 'cuda:0'

model.to(device)


# Initialize tensorboard writer
writer = SummaryWriter()

# Get optimizer and scheduler
optim_config = model.configure_optimizers()
optimizer = optim_config['optimizer']
lr_scheduler = optim_config['lr_scheduler']

num_epochs = 30
best_val_loss = float('inf')

# Create a tqdm progress bar for epochs
epoch_bar = tqdm(range(num_epochs), desc="Training", position=0)

for epoch in epoch_bar:
    model.train()
    train_loss = 0
    
    # Create a tqdm progress bar for batches
    batch_bar = tqdm(train_dataloader, desc=f"Epoch {epoch}", position=1, leave=False)
    
    for batch_idx, batch in enumerate(batch_bar):
        batch = {b: batch[b].to(device) for b in batch}
        optimizer.zero_grad()

        eeg_embeddings, text_embeddings = model(batch)
        loss = model._compute_losses(eeg_embeddings, text_embeddings).mean()
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        
        # Update batch progress bar
        batch_bar.set_postfix({
            'loss': f"{loss.item():.4f}",
            'lr': f"{optimizer.param_groups[0]['lr']:.2e}"
        })
        
        # Log training loss
        writer.add_scalar('Loss/train', loss.item(), epoch * len(train_dataloader) + batch_idx)
    
    avg_train_loss = train_loss / len(train_dataloader)
    
    # Validation loop
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch in val_dataloader:
            batch = {b: batch[b].to(device) for b in batch}
            eeg_embeddings, text_embeddings = model(batch)
            loss = model._compute_losses(eeg_embeddings, text_embeddings).mean()
            val_loss += loss.item()
    
    avg_val_loss = val_loss / len(val_dataloader)
    
    # Log validation loss
    writer.add_scalar('Loss/val', avg_val_loss, epoch)
    
    # Learning rate scheduler step
    # lr_scheduler.step(avg_val_loss) #TURNED THIS OFF 7/23!!!
    
    # Log learning rate
    writer.add_scalar('Learning Rate', optimizer.param_groups[0]['lr'], epoch)
    
    # Save best model
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), 'best_model.pth')
    
    # Update epoch progress bar
    epoch_bar.set_postfix({
        'train_loss': f"{avg_train_loss:.4f}",
        'val_loss': f"{avg_val_loss:.4f}",
        'lr': f"{optimizer.param_groups[0]['lr']:.2e}",
        'best_val_loss': f"{best_val_loss:.4f}"
    })

# Close tensorboard writer
writer.close()
# Out:
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1063 [00:00<?, ?it/s]
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [417,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [418,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [415,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ...
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [414,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 34
#      31 batch = {b: batch[b].to(device) for b in batch}
#      32 optimizer.zero_grad()
# ---> 34 eeg_embeddings, text_embeddings = model(batch)
#      35 loss = model._compute_losses(eeg_embeddings, text_embeddings).mean()
#      36 loss.backward()
#
# File /raid/spanchavati/anaconda3/envs/eegtext/lib/python3.8/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /raid/spanchavati/anaconda3/envs/eegtext/lib/python3.8/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /raid/spanchavati/Mamba-BCI-Journal-of-Neural-Engineering/EEG_Text/models.py:196, in EEGTextCLIP.forward(self, inputs)
#     194 text = {'input_ids': inputs['input_ids'],'attention_mask': inputs['attention_mask']}
#     195 eeg_features = self.eeg_encoder(eeg, eeg_mask, pid)
# --> 196 text_features = self.text_encoder(text)
#     198 eeg_embeddings = self.eeg_proj(eeg_features)
#     199 text_embeddings = self.text_proj(text_features)
#
# File /raid/spanchavati/anaconda3/envs/eegtext/lib/python3.8/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /raid/spanchavati/anaconda3/envs/eegtext/lib/python3.8/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /raid/spanchavati/Mamba-BCI-Journal-of-Neural-Engineering/EEG_Text/models.py:363, in HuggingFaceEncoder.forward(self, inputs, pooling)
#     352 """
#     353 Get the embedding for the given text using the specified pooling method.
#     354
#    (...)
#     360 torch.Tensor: The computed embedding.
#     361 """
#     362 # inputs = self.tokenizer(text, return_tensors='pt', padding=True, truncation=True, is_split_into_words=isinstance(text, list))
# --> 363 outputs = self.model(**inputs)
#     365 if pooling == 'mean':
#     366     return torch.mean(outputs.last_hidden_state, dim=1)
#
# File /raid/spanchavati/anaconda3/envs/eegtext/lib/python3.8/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /raid/spanchavati/anaconda3/envs/eegtext/lib/python3.8/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /raid/spanchavati/anaconda3/envs/eegtext/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py:1107, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1100         extended_attention_mask = _prepare_4d_causal_attention_mask_for_sdpa(
#    1101             attention_mask,
#    1102             input_shape,
#    1103             embedding_output,
#    1104             past_key_values_length,
#    1105         )
#    1106     else:
# -> 1107         extended_attention_mask = _prepare_4d_attention_mask_for_sdpa(
#    1108             attention_mask, embedding_output.dtype, tgt_len=seq_length
#    1109         )
#    1110 else:
#    1111     # We can provide a self-attention mask of dimensions [batch_size, from_seq_length, to_seq_length]
#    1112     # ourselves in which case we just need to make it broadcastable to all heads.
#    1113     extended_attention_mask = self.get_extended_attention_mask(attention_mask, input_shape)
#
# File /raid/spanchavati/anaconda3/envs/eegtext/lib/python3.8/site-packages/transformers/modeling_attn_mask_utils.py:449, in _prepare_4d_attention_mask_for_sdpa(mask, dtype, tgt_len)
#     442 is_tracing = (
#     443     torch.jit.is_tracing()
#     444     or isinstance(mask, torch.fx.Proxy)
#     445     or (hasattr(torch, "_dynamo") and torch._dynamo.is_compiling())
#     446 )
#     448 # torch.jit.trace, symbolic_trace and torchdynamo with fullgraph=True are unable to capture data-dependent controlflows.
# --> 449 if not is_tracing and torch.all(mask == 1):
#     450     return None
#     451 else:
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
with torch.no_grad():
    torch.cuda.empty_cache()

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def get_unique_sentences(data_dict):
    unique_sentences = {}
    for key, patient_data in data_dict.items():
        for sentence in patient_data['content']:
            if sentence not in unique_sentences:
                unique_sentences[sentence] = len(unique_sentences)
    return unique_sentences

def embed_unique_sentences(model, unique_sentences, tokenizer):
    model.eval()
    sentence_order = list(unique_sentences.keys())
    inputs = tokenizer(sentence_order, return_tensors='pt', padding=True, truncation=True)
    with torch.no_grad():
        text_features = model.text_encoder(inputs.to(device))
        text_embeddings = model.text_proj(text_features.to(device))
    return text_embeddings, sentence_order

def embed_eeg_data(model, dataloader):
    model.eval()
    eeg_embeddings = []
    with torch.no_grad():
        for batch in dataloader:
            batch = {b: batch[b].to(device) for b in batch}
            
            eeg_embeds, _ = model(batch)
            eeg_embeddings.append(eeg_embeds)
    eeg_embeddings = torch.cat(eeg_embeddings)
    return eeg_embeddings

def compute_similarity(embeddings1, embeddings2):
    return cosine_similarity(embeddings1.cpu().numpy(), embeddings2.cpu().numpy())

def retrieve_closest(similarity_matrix, sentence_order, top_k=5):
    closest_indices = np.argsort(-similarity_matrix, axis=1)[:, :top_k]
    closest_sentences = [[sentence_order[idx] for idx in row] for row in closest_indices]
    return closest_sentences

# %%
train_dataloader = DataLoader(train_ds, batch_size=32, shuffle=False, num_workers=4)
val_dataloader = DataLoader(val_ds, batch_size=32, shuffle=False, num_workers=4)
test_dataloader = DataLoader(test_ds, batch_size = 32, shuffle = False, num_workers = 4)

unique_sentences = get_unique_sentences(dataset_dict)
text_embeddings, sentence_order = embed_unique_sentences(model, unique_sentences, tokenizer)

# %%
# Embed EEG data
train_eeg_embeddings = embed_eeg_data(model, train_dataloader)
val_eeg_embeddings = embed_eeg_data(model, val_dataloader)
test_eeg_embeddings = embed_eeg_data(model, test_dataloader)


# Compute similarities
train_similarity_matrix = compute_similarity(train_eeg_embeddings, text_embeddings)
val_similarity_matrix = compute_similarity(val_eeg_embeddings, text_embeddings)
test_similarity_matrix = compute_similarity(test_eeg_embeddings, text_embeddings)


# Retrieve closest matches
train_closest_matches = retrieve_closest(train_similarity_matrix, sentence_order)
val_closest_matches = retrieve_closest(val_similarity_matrix, sentence_order)
test_closest_matches = retrieve_closest(test_similarity_matrix, sentence_order)


# Example: print the closest matches for the first EEG embedding in the validation set
print("Top matches for the first EEG embedding in the validation set:")
for sentence in val_closest_matches[0]:
    print(f"Sentence: {sentence}, Similarity: {val_similarity_matrix[0, unique_sentences[sentence]]:.4f}")

# %%
sentence_order[10]

# %%
idx = 10

#Example: print the closest matches for the first EEG embedding in the validation set
print("Top matches for the first EEG embedding in the validation set:")
for sentence in train_closest_matches[idx]:
    print(f"Sentence: {sentence}, Similarity: {train_similarity_matrix[idx, unique_sentences[sentence]]:.4f}")


tokenizer.decode(train_ds[idx]['input_ids'], True)

# %%
# len(sentence_order)
